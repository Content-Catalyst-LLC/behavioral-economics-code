# %% [markdown]
# # Choice Architecture Policy Evaluation
#
# Economist-facing notebook scaffold for *Choice Architecture and Decision Environments*.
#
# Run `python/generate_synthetic_choice_architecture_panel.py` and `python/causal_choice_architecture_evaluation.py` before opening this notebook.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
effects_path = root / 'outputs' / 'regression_tables' / 'python_choice_architecture_treatment_effects.csv'
summary_path = root / 'outputs' / 'tables' / 'choice_architecture_welfare_summary.csv'

if effects_path.exists():
    display(pd.read_csv(effects_path))
else:
    print('Run python/causal_choice_architecture_evaluation.py first.')

if summary_path.exists():
    display(pd.read_csv(summary_path))
else:
    print('Run python/choice_architecture_welfare_analysis.py first.')
