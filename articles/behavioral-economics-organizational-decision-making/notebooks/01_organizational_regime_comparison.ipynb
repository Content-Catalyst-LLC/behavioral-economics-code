# %% [markdown]
# # Organizational Regime Comparison
#
# Synthetic notebook scaffold for the article *Behavioral Economics in Organizational Decision-Making*.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
summary_path = root / 'outputs' / 'tables' / 'organizational_regime_summary.csv'
print(summary_path)
if summary_path.exists():
    display(pd.read_csv(summary_path))
else:
    print('Run python/organizational_regime_simulation.py first.')
