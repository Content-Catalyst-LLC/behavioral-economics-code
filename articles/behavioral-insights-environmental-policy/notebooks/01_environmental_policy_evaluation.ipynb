# %% [markdown]
# # Environmental Policy Evaluation
#
# Economist-facing notebook scaffold for *Behavioral Insights in Environmental Policy*.
#
# Run `python/generate_synthetic_environmental_policy_panel.py` and `python/causal_environmental_policy_evaluation.py` before opening this notebook.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
effects_path = root / 'outputs' / 'regression_tables' / 'python_environmental_policy_treatment_effects.csv'
summary_path = root / 'outputs' / 'tables' / 'environmental_policy_welfare_summary.csv'

if effects_path.exists():
    display(pd.read_csv(effects_path))
else:
    print('Run python/causal_environmental_policy_evaluation.py first.')

if summary_path.exists():
    display(pd.read_csv(summary_path))
else:
    print('Run python/environmental_welfare_analysis.py first.')
