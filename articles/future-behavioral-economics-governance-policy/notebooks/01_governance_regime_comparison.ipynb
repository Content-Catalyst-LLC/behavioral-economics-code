# %% [markdown]
# # Governance Regime Comparison
#
# Synthetic notebook scaffold for the article *The Future of Behavioral Economics in Governance and Policy*.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
summary_path = root / 'outputs' / 'tables' / 'regime_summary.csv'
print(summary_path)
if summary_path.exists():
    display(pd.read_csv(summary_path))
else:
    print('Run python/governance_regime_simulation.py first.')
