# %% [markdown]
# # Nudge Policy Evaluation
#
# Economist-facing notebook scaffold for *Nudge Theory and Behavioral Public Policy*.
#
# Run `python/generate_synthetic_nudge_policy_panel.py` and `python/causal_nudge_policy_evaluation.py` before opening this notebook.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
effects_path = root / 'outputs' / 'regression_tables' / 'python_nudge_policy_treatment_effects.csv'
summary_path = root / 'outputs' / 'tables' / 'nudge_policy_welfare_summary.csv'

if effects_path.exists():
    display(pd.read_csv(effects_path))
else:
    print('Run python/causal_nudge_policy_evaluation.py first.')

if summary_path.exists():
    display(pd.read_csv(summary_path))
else:
    print('Run python/nudge_welfare_analysis.py first.')
